# %%
import pandas as pd

# %%
weather = pd.read_csv("data/ny_weather_data.csv", index_col="DATE", low_memory=False)

# %%
weather
# Out:
#                 STATION                                       NAME  LATITUDE  \
# DATE
# 1963-09-05  USW00004781          ISLIP LI MACARTHUR AIRPORT, NY US  40.79389
# 1963-09-06  USW00004781          ISLIP LI MACARTHUR AIRPORT, NY US  40.79389
# 1963-09-07  USW00004781          ISLIP LI MACARTHUR AIRPORT, NY US  40.79389
# 1963-09-08  USW00004781          ISLIP LI MACARTHUR AIRPORT, NY US  40.79389
# 1963-09-09  USW00004781          ISLIP LI MACARTHUR AIRPORT, NY US  40.79389
# ...                 ...                                        ...       ...
# 2024-05-12  USW00003177  CARLSBAD MCCLELLAN PALOMAR AIRPORT, CA US  33.12993
# 2024-05-13  USW00003177  CARLSBAD MCCLELLAN PALOMAR AIRPORT, CA US  33.12993
# 2024-05-14  USW00003177  CARLSBAD MCCLELLAN PALOMAR AIRPORT, CA US  33.12993
# 2024-05-15  USW00003177  CARLSBAD MCCLELLAN PALOMAR AIRPORT, CA US  33.12993
# 2024-05-16  USW00003177  CARLSBAD MCCLELLAN PALOMAR AIRPORT, CA US  33.12993
#
#             LONGITUDE  ELEVATION  AWND AWND_ATTRIBUTES  FMTM FMTM_ATTRIBUTES  \
# DATE
# 1963-09-05  -73.10181       25.4   NaN             NaN   NaN             NaN
# 1963-09-06  -73.10181       25.4   NaN             NaN   NaN             NaN
# 1963-09-07  -73.10181       25.4   NaN             NaN   NaN             NaN
# 1963-09-08  -73.10181       25.4   NaN             NaN   NaN             NaN
# 1963-09-09  -73.10181       25.4   NaN             NaN   NaN             NaN
# ...               ...        ...   ...             ...   ...             ...
# 2024-05-12 -117.27651       95.3   1.7             ,,W   NaN             NaN
# 2024-05-13 -117.27651       95.3   1.7             ,,W   NaN             NaN
# 2024-05-14 -117.27651       95.3   2.2             ,,W   NaN             NaN
# 2024-05-15 -117.27651       95.3   2.2             ,,W   NaN             NaN
# 2024-05-16 -117.27651       95.3   NaN             NaN   NaN             NaN
#
#             PGTM  ... WT19  WT19_ATTRIBUTES WT21  WT21_ATTRIBUTES WT22  \
# DATE              ...
# 1963-09-05   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 1963-09-06   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 1963-09-07   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 1963-09-08   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 1963-09-09   NaN  ...  NaN              NaN  NaN              NaN  NaN
# ...          ...  ...  ...              ...  ...              ...  ...
# 2024-05-12   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 2024-05-13   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 2024-05-14   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 2024-05-15   NaN  ...  NaN              NaN  NaN              NaN  NaN
# 2024-05-16   NaN  ...  NaN              NaN  NaN              NaN  NaN
#
#             WT22_ATTRIBUTES WV03  WV03_ATTRIBUTES WV20  WV20_ATTRIBUTES
# DATE
# 1963-09-05              NaN  NaN              NaN  NaN              NaN
# 1963-09-06              NaN  NaN              NaN  NaN              NaN
# 1963-09-07              NaN  NaN              NaN  NaN              NaN
# 1963-09-08              NaN  NaN              NaN  NaN              NaN
# 1963-09-09              NaN  NaN              NaN  NaN              NaN
# ...                     ...  ...              ...  ...              ...
# 2024-05-12              NaN  NaN              NaN  NaN              NaN
# 2024-05-13              NaN  NaN              NaN  NaN              NaN
# 2024-05-14              NaN  NaN              NaN  NaN              NaN
# 2024-05-15              NaN  NaN              NaN  NaN              NaN
# 2024-05-16              NaN  NaN              NaN  NaN              NaN
#
# [31746 rows x 81 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION            0.000000
# NAME               0.000000
# LATITUDE           0.000000
# LONGITUDE          0.000000
# ELEVATION          0.000000
#                      ...
# WT22_ATTRIBUTES    0.998204
# WV03               0.999716
# WV03_ATTRIBUTES    0.999716
# WV20               0.999968
# WV20_ATTRIBUTES    0.999968
# Length: 81, dtype: float64

# %%
core_weather = weather[['PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN']].copy()

# %%
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1963-09-05     0.0   0.0         0.0      17.8      11.7
# 1963-09-06     5.6   0.0         0.0      15.0      12.2
# 1963-09-07     0.0   0.0         0.0      22.8      10.0
# 1963-09-08     0.0   0.0         0.0      25.0      11.1
# 1963-09-09     0.0   0.0         0.0      23.9      11.1
# ...            ...   ...         ...       ...       ...
# 2024-05-13     0.0   0.0         0.0      17.8       5.6
# 2024-05-14     0.0   0.0         0.0      19.4      11.7
# 2024-05-15    34.3   0.0         0.0      16.7      13.9
# 2024-05-16     2.5   0.0         0.0      18.3      14.4
# 2024-05-17     NaN   NaN         NaN       NaN       NaN
#
# [22164 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.000271
# snow          0.000271
# snow_depth    0.006091
# temp_max      0.000045
# temp_min      0.000045
# dtype: float64

# %%
core_weather['snow'].value_counts()
# Out:
# snow
# 0.0      21429
# 25.0        77
# 3.0         60
# 51.0        57
# 5.0         45
#          ...
# 132.0        1
# 122.0        1
# 257.0        1
# 71.0         1
# 597.0        1
# Name: count, Length: 95, dtype: int64

# %%
del core_weather['snow']

# %%
core_weather
# Out:
#             precip  snow  temp_max  temp_min
# DATE
# 1963-09-05     0.0   0.0      17.8      11.7
# 1963-09-06     5.6   0.0      15.0      12.2
# 1963-09-07     0.0   0.0      22.8      10.0
# 1963-09-08     0.0   0.0      25.0      11.1
# 1963-09-09     0.0   0.0      23.9      11.1
# ...            ...   ...       ...       ...
# 2024-05-13     0.0   0.0      17.8       5.6
# 2024-05-14     0.0   0.0      19.4      11.7
# 2024-05-15    34.3   0.0      16.7      13.9
# 2024-05-16     2.5   0.0      18.3      14.4
# 2024-05-17     NaN   NaN       NaN       NaN
#
# [22164 rows x 4 columns]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip   snow  temp_max  temp_min
# DATE
# 1965-03-17     NaN   13.0       6.7      -2.2
# 1965-03-18     NaN    0.0       4.4       1.1
# 1994-02-23     NaN  102.0       1.1      -2.2
# 1997-02-14     NaN    NaN       9.4      -2.2
# 1998-02-05     NaN    0.0       1.7       0.6
# 2024-05-17     NaN    NaN       NaN       NaN

# %%
core_weather['precip'] = core_weather['precip'].fillna(0)

# %%
core_weather
# Out:
#             precip  snow  temp_max  temp_min
# DATE
# 1963-09-05     0.0   0.0      17.8      11.7
# 1963-09-06     5.6   0.0      15.0      12.2
# 1963-09-07     0.0   0.0      22.8      10.0
# 1963-09-08     0.0   0.0      25.0      11.1
# 1963-09-09     0.0   0.0      23.9      11.1
# ...            ...   ...       ...       ...
# 2024-05-13     0.0   0.0      17.8       5.6
# 2024-05-14     0.0   0.0      19.4      11.7
# 2024-05-15    34.3   0.0      16.7      13.9
# 2024-05-16     2.5   0.0      18.3      14.4
# 2024-05-17     0.0   NaN       NaN       NaN
#
# [22164 rows x 4 columns]

# %%
core_weather = core_weather.fillna(method='ffill')
# Out:
# /var/folders/s5/01cn7h8s30xg7zdbxvfl8zr00000gp/T/ipykernel_77124/1491947136.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   core_weather = core_weather.fillna(method='ffill')

# %%
core_weather
# Out:
#             precip  snow  temp_max  temp_min
# DATE
# 1963-09-05     0.0   0.0      17.8      11.7
# 1963-09-06     5.6   0.0      15.0      12.2
# 1963-09-07     0.0   0.0      22.8      10.0
# 1963-09-08     0.0   0.0      25.0      11.1
# 1963-09-09     0.0   0.0      23.9      11.1
# ...            ...   ...       ...       ...
# 2024-05-13     0.0   0.0      17.8       5.6
# 2024-05-14     0.0   0.0      19.4      11.7
# 2024-05-15    34.3   0.0      16.7      13.9
# 2024-05-16     2.5   0.0      18.3      14.4
# 2024-05-17     0.0   0.0      18.3      14.4
#
# [22164 rows x 4 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip      0.0
# snow        0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index.year
# Out:
# Index([1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963,
#        ...
#        2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#       dtype='int32', name='DATE', length=22164)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip      0
# snow        0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather['target'] = core_weather.shift(-1)['temp_max']

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1963-09-05     0.0      17.8      11.7    15.0
# 1963-09-06     5.6      15.0      12.2    22.8
# 1963-09-07     0.0      22.8      10.0    25.0
# 1963-09-08     0.0      25.0      11.1    23.9
# 1963-09-09     0.0      23.9      11.1    26.1
# ...            ...       ...       ...     ...
# 2024-05-13     0.0      17.8       5.6    19.4
# 2024-05-14     0.0      19.4      11.7    16.7
# 2024-05-15    34.3      16.7      13.9    18.3
# 2024-05-16     2.5      18.3      14.4    18.3
# 2024-05-17     0.0      18.3      14.4     NaN
#
# [22164 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1963-09-05     0.0      17.8      11.7    15.0
# 1963-09-06     5.6      15.0      12.2    22.8
# 1963-09-07     0.0      22.8      10.0    25.0
# 1963-09-08     0.0      25.0      11.1    23.9
# 1963-09-09     0.0      23.9      11.1    26.1
# ...            ...       ...       ...     ...
# 2024-05-12     0.0      13.3       7.2    17.8
# 2024-05-13     0.0      17.8       5.6    19.4
# 2024-05-14     0.0      19.4      11.7    16.7
# 2024-05-15    34.3      16.7      13.9    18.3
# 2024-05-16     2.5      18.3      14.4    18.3
#
# [22163 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ['precip', 'temp_max', 'temp_min']

# %%
train = core_weather.loc[:"2022-12-31"]

# %%
test = core_weather.loc["2023-01-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 2.9011398490829734

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2023-01-01    12.2    12.640259
# 2023-01-02    12.2    12.157653
# 2023-01-03    18.3    13.487860
# 2023-01-04    11.1    18.298037
# 2023-01-05     8.3    12.660955
# ...            ...          ...
# 2024-05-12    17.8    14.432859
# 2024-05-13    19.4    16.928228
# 2024-05-14    16.7    19.700550
# 2024-05-15    18.3    17.188535
# 2024-05-16    18.3    19.643707
#
# [502 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-0.03980471,  0.65503041,  0.28266775])

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2022-12-31"]
    test = core_weather.loc["2023-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_absolute_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
core_weather['month_max'] = core_weather['temp_max'].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max
# DATE
# 1963-09-05     0.0      17.8      11.7    15.0        NaN
# 1963-09-06     5.6      15.0      12.2    22.8        NaN
# 1963-09-07     0.0      22.8      10.0    25.0        NaN
# 1963-09-08     0.0      25.0      11.1    23.9        NaN
# 1963-09-09     0.0      23.9      11.1    26.1        NaN
# ...            ...       ...       ...     ...        ...
# 2024-05-12     0.0      13.3       7.2    17.8  16.563333
# 2024-05-13     0.0      17.8       5.6    19.4  16.750000
# 2024-05-14     0.0      19.4      11.7    16.7  16.823333
# 2024-05-15    34.3      16.7      13.9    18.3  16.526667
# 2024-05-16     2.5      18.3      14.4    18.3  16.433333
#
# [22163 rows x 5 columns]

# %%
core_weather['month_day_max'] = core_weather['month_max'] / core_weather['temp_max']

# %%
core_weather['max_min'] = core_weather['temp_max'] / core_weather['temp_min']

# %%
predictors = ['precip', 'temp_max', 'temp_min', 'month_max']

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1963-12-07     0.0       8.3      -1.1    12.2  11.520000       1.387952
# 1963-12-08     2.0      12.2      -3.3    12.8  11.406667       0.934973
# 1963-12-09    11.7      12.8      -0.6     5.0  11.353333       0.886979
# 1963-12-10     0.0       5.0      -1.1     2.2  10.946667       2.189333
# 1963-12-11     0.0       2.2      -2.8     3.3  10.556667       4.798485
# ...            ...       ...       ...     ...        ...            ...
# 2024-05-12     0.0      13.3       7.2    17.8  16.563333       1.245363
# 2024-05-13     0.0      17.8       5.6    19.4  16.750000       0.941011
# 2024-05-14     0.0      19.4      11.7    16.7  16.823333       0.867182
# 2024-05-15    34.3      16.7      13.9    18.3  16.526667       0.989621
# 2024-05-16     2.5      18.3      14.4    18.3  16.433333       0.897996
#
#               max_min
# DATE
# 1963-12-07  -7.545455
# 1963-12-08  -3.696970
# 1963-12-09 -21.333333
# 1963-12-10  -4.545455
# 1963-12-11  -0.785714
# ...               ...
# 2024-05-12   1.847222
# 2024-05-13   3.178571
# 2024-05-14   1.658120
# 2024-05-15   1.201439
# 2024-05-16   1.270833
#
# [22073 rows x 7 columns]

# %%
error, combined = create_predictions(predictors, core_weather, reg)
# Out:
# /Users/colin1/miniconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 error, combined = create_predictions(predictors, core_weather, reg)
#
# Cell In[102], line 5, in create_predictions(predictors, core_weather, reg)
#       2 train = core_weather.loc[:"2022-12-31"]
#       3 test = core_weather.loc["2023-01-01":]
# ----> 5 reg.fit(train[predictors], train["target"])
#       6 predictions = reg.predict(test[predictors])
#       8 error = mean_absolute_error(test["target"], predictions)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:1167, in Ridge.fit(self, X, y, sample_weight)
#    1147 """Fit Ridge regression model.
#    1148
#    1149 Parameters
#    (...)
#    1164     Fitted estimator.
#    1165 """
#    1166 _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
# -> 1167 X, y = self._validate_data(
#    1168     X,
#    1169     y,
#    1170     accept_sparse=_accept_sparse,
#    1171     dtype=[np.float64, np.float32],
#    1172     multi_output=True,
#    1173     y_numeric=True,
#    1174 )
#    1175 return super().fit(X, y, sample_weight=sample_weight)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip           0.0
# temp_max         0.0
# temp_min         0.0
# target           0.0
# month_max        0.0
# month_day_max    0.0
# max_min          0.0
# dtype: float64

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1963-12-07     0.0       8.3      -1.1    12.2  11.520000       1.387952
# 1963-12-08     2.0      12.2      -3.3    12.8  11.406667       0.934973
# 1963-12-09    11.7      12.8      -0.6     5.0  11.353333       0.886979
# 1963-12-10     0.0       5.0      -1.1     2.2  10.946667       2.189333
# 1963-12-11     0.0       2.2      -2.8     3.3  10.556667       4.798485
# ...            ...       ...       ...     ...        ...            ...
# 2024-05-12     0.0      13.3       7.2    17.8  16.563333       1.245363
# 2024-05-13     0.0      17.8       5.6    19.4  16.750000       0.941011
# 2024-05-14     0.0      19.4      11.7    16.7  16.823333       0.867182
# 2024-05-15    34.3      16.7      13.9    18.3  16.526667       0.989621
# 2024-05-16     2.5      18.3      14.4    18.3  16.433333       0.897996
#
#               max_min
# DATE
# 1963-12-07  -7.545455
# 1963-12-08  -3.696970
# 1963-12-09 -21.333333
# 1963-12-10  -4.545455
# 1963-12-11  -0.785714
# ...               ...
# 2024-05-12   1.847222
# 2024-05-13   3.178571
# 2024-05-14   1.658120
# 2024-05-15   1.201439
# 2024-05-16   1.270833
#
# [22073 rows x 7 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
predictors
# Out:
# ['precip', 'temp_max', 'temp_min']

# %%
error
# Out:
# 2.7721609414191364

# %%
core_weather['monthly_avg'] = (core_weather['temp_max'].groupby(core_weather.index.month).transform(lambda x: x.expanding(1).mean()))

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1963-12-07     0.0       8.3      -1.1    12.2  11.520000       1.387952
# 1963-12-08     2.0      12.2      -3.3    12.8  11.406667       0.934973
# 1963-12-09    11.7      12.8      -0.6     5.0  11.353333       0.886979
# 1963-12-10     0.0       5.0      -1.1     2.2  10.946667       2.189333
# 1963-12-11     0.0       2.2      -2.8     3.3  10.556667       4.798485
# ...            ...       ...       ...     ...        ...            ...
# 2024-05-12     0.0      13.3       7.2    17.8  16.563333       1.245363
# 2024-05-13     0.0      17.8       5.6    19.4  16.750000       0.941011
# 2024-05-14     0.0      19.4      11.7    16.7  16.823333       0.867182
# 2024-05-15    34.3      16.7      13.9    18.3  16.526667       0.989621
# 2024-05-16     2.5      18.3      14.4    18.3  16.433333       0.897996
#
#               max_min  monthly_avg
# DATE
# 1963-12-07  -7.545455     8.300000
# 1963-12-08  -3.696970    10.250000
# 1963-12-09 -21.333333    11.100000
# 1963-12-10  -4.545455     9.575000
# 1963-12-11  -0.785714     8.100000
# ...               ...          ...
# 2024-05-12   1.847222    19.965794
# 2024-05-13   3.178571    19.964637
# 2024-05-14   1.658120    19.964335
# 2024-05-15   1.201439    19.962593
# 2024-05-16   1.270833    19.961707
#
# [22073 rows x 8 columns]

# %%
core_weather['day_of_year_avg'] = (core_weather['temp_max'].groupby(core_weather.index.day_of_year).transform(lambda x: x.expanding(1).mean()))

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1963-12-07     0.0       8.3      -1.1    12.2  11.520000       1.387952
# 1963-12-08     2.0      12.2      -3.3    12.8  11.406667       0.934973
# 1963-12-09    11.7      12.8      -0.6     5.0  11.353333       0.886979
# 1963-12-10     0.0       5.0      -1.1     2.2  10.946667       2.189333
# 1963-12-11     0.0       2.2      -2.8     3.3  10.556667       4.798485
# ...            ...       ...       ...     ...        ...            ...
# 2024-05-12     0.0      13.3       7.2    17.8  16.563333       1.245363
# 2024-05-13     0.0      17.8       5.6    19.4  16.750000       0.941011
# 2024-05-14     0.0      19.4      11.7    16.7  16.823333       0.867182
# 2024-05-15    34.3      16.7      13.9    18.3  16.526667       0.989621
# 2024-05-16     2.5      18.3      14.4    18.3  16.433333       0.897996
#
#               max_min  monthly_avg  day_of_year_avg
# DATE
# 1963-12-07  -7.545455     8.300000         8.300000
# 1963-12-08  -3.696970    10.250000        12.200000
# 1963-12-09 -21.333333    11.100000        12.800000
# 1963-12-10  -4.545455     9.575000         5.000000
# 1963-12-11  -0.785714     8.100000         2.200000
# ...               ...          ...              ...
# 2024-05-12   1.847222    19.965794        18.649180
# 2024-05-13   3.178571    19.964637        19.437705
# 2024-05-14   1.658120    19.964335        19.868852
# 2024-05-15   1.201439    19.962593        19.768852
# 2024-05-16   1.270833    19.961707        20.247541
#
# [22073 rows x 9 columns]

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
predictors = ['precip', 'temp_max', 'temp_min', 'month_max', 'monthly_avg', 'day_of_year_avg']

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# 2.702353535325597

# %%
reg.coef_
# Out:
# array([-0.02893519,  0.48458624,  0.11081034,  0.03442367,  0.12662025,
#         0.24324229])

# %%
core_weather.corr()['target']
# Out:
# precip            -0.034135
# temp_max           0.914175
# temp_min           0.886454
# target             1.000000
# month_max          0.867741
# month_day_max      0.025422
# max_min            0.149530
# monthly_avg        0.885584
# day_of_year_avg    0.897765
# Name: target, dtype: float64

# %%
combined['diff'] = (combined['actual'] - combined['predictions']).abs()

# %%
combined.sort_values('diff', ascending=False).head(20)
# Out:
#             actual  predictions       diff
# DATE
# 2023-04-05    25.6    13.509579  12.090421
# 2023-02-15    21.7    10.270804  11.429196
# 2023-04-11    28.3    17.610812  10.689188
# 2024-04-28    27.8    17.554149  10.245851
# 2024-04-14    25.6    16.014304   9.585696
# 2023-01-03    18.3     9.464011   8.835989
# 2024-03-02    17.8     9.052324   8.747676
# 2023-02-09    16.7     8.160119   8.539881
# 2023-03-25    17.2     8.760206   8.439794
# 2023-02-24    -1.0     7.252952   8.252952
# 2023-02-19    16.1     7.862987   8.237013
# 2023-01-11    13.3     5.229421   8.070579
# 2024-03-13    20.0    11.985109   8.014891
# 2024-03-14    22.8    14.898491   7.901509
# 2024-01-08    12.8     5.092845   7.707155
# 2023-12-14    13.3     5.632802   7.667198
# 2023-04-10    21.7    14.063425   7.636575
# 2024-01-14    -1.6     6.028952   7.628952
# 2023-10-27    28.3    20.678832   7.621168
# 2024-05-09    12.2    19.667116   7.467116

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1963-12-07     0.0       8.3      -1.1    12.2  11.520000       1.387952
# 1963-12-08     2.0      12.2      -3.3    12.8  11.406667       0.934973
# 1963-12-09    11.7      12.8      -0.6     5.0  11.353333       0.886979
# 1963-12-10     0.0       5.0      -1.1     2.2  10.946667       2.189333
# 1963-12-11     0.0       2.2      -2.8     3.3  10.556667       4.798485
# ...            ...       ...       ...     ...        ...            ...
# 2024-05-12     0.0      13.3       7.2    17.8  16.563333       1.245363
# 2024-05-13     0.0      17.8       5.6    19.4  16.750000       0.941011
# 2024-05-14     0.0      19.4      11.7    16.7  16.823333       0.867182
# 2024-05-15    34.3      16.7      13.9    18.3  16.526667       0.989621
# 2024-05-16     2.5      18.3      14.4    18.3  16.433333       0.897996
#
#               max_min  monthly_avg  day_of_year_avg
# DATE
# 1963-12-07  -7.545455     8.300000         8.300000
# 1963-12-08  -3.696970    10.250000        12.200000
# 1963-12-09 -21.333333    11.100000        12.800000
# 1963-12-10  -4.545455     9.575000         5.000000
# 1963-12-11  -0.785714     8.100000         2.200000
# ...               ...          ...              ...
# 2024-05-12   1.847222    19.965794        18.649180
# 2024-05-13   3.178571    19.964637        19.437705
# 2024-05-14   1.658120    19.964335        19.868852
# 2024-05-15   1.201439    19.962593        19.768852
# 2024-05-16   1.270833    19.961707        20.247541
#
# [22073 rows x 9 columns]

# %%
combined
# Out:
#             actual  predictions      diff
# DATE
# 2023-01-01    12.2     9.674603  2.525397
# 2023-01-02    12.2     9.273731  2.926269
# 2023-01-03    18.3     9.464011  8.835989
# 2023-01-04    11.1    12.936284  1.836284
# 2023-01-05     8.3     9.024165  0.724165
# ...            ...          ...       ...
# 2024-05-12    17.8    16.154291  1.645709
# 2024-05-13    19.4    18.355714  1.044286
# 2024-05-14    16.7    19.914355  3.214355
# 2024-05-15    18.3    17.822521  0.477479
# 2024-05-16    18.3    19.686515  1.386515
#
# [502 rows x 3 columns]
